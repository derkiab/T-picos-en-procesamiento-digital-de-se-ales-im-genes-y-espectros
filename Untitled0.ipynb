# %% [markdown]
# <a href="https://colab.research.google.com/github/derkiab/Topicos-en-procesamiento-digital-de-senales-imagenes-y-espectros/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('datasetnormalized80.csv', sep=';')
dataset
# Out:
#        agua domo n eficiencia n flujo aire n  flujo gas n flujo petroleo n  \
# 0                0  0,752021182  0,809979712  0,884609892      0,650793651
# 1      0,004687784  0,587610687  0,733823403  0,753106107      0,650793651
# 2      0,005413244  0,546342068  0,834019223  0,691745609              0,6
# 3      0,007366534  0,603889339  0,733542677  0,748298186      0,650793651
# 4      0,014063297  0,575687954  0,737248261   0,75762841      0,650793651
# ...            ...          ...          ...          ...              ...
# 53681  0,875706152  0,300121153  0,805711324  0,514411598      0,815873016
# 53682  0,902643701  0,390464786            1  0,387062708      0,815873016
# 53683  0,956024285  0,404622929  0,993864657  0,394892179      0,815873016
# 53684  0,982600772  0,367671861  0,998402543  0,515045249      0,815873016
# 53685            1  0,418738637  0,999853481  0,479506831      0,815873016
#
#       Flujo vapor n         O2 n Presion general n Presion vapor n
# ...

# %%
Y = pd.DataFrame(dataset.iloc[:,1])

Y
# Out:
#       eficiencia n
# 0      0,752021182
# 1      0,587610687
# 2      0,546342068
# 3      0,603889339
# 4      0,575687954
# ...            ...
# 53681  0,300121153
# 53682  0,390464786
# 53683  0,404622929
# 53684  0,367671861
# 53685  0,418738637
#
# [53686 rows x 1 columns]

# %%
X = pd.DataFrame(dataset.iloc[:, [0, 2, 3, 4, 5, 6, 7]])
X
# Out:
#        agua domo n flujo aire n  flujo gas n flujo petroleo n Flujo vapor n  \
# 0                0  0,809979712  0,884609892      0,650793651   0,802833137
# 1      0,004687784  0,733823403  0,753106107      0,650793651   0,626506688
# 2      0,005413244  0,834019223  0,691745609              0,6   0,578449771
# 3      0,007366534  0,733542677  0,748298186      0,650793651   0,643467963
# 4      0,014063297  0,737248261   0,75762841      0,650793651     0,6141391
# ...            ...          ...          ...              ...           ...
# 53681  0,875706152  0,805711324  0,514411598      0,815873016   0,354718143
# 53682  0,902643701            1  0,387062708      0,815873016   0,453676627
# 53683  0,956024285  0,993864657  0,394892179      0,815873016   0,469261651
# 53684  0,982600772  0,998402543  0,515045249      0,815873016   0,428821584
# 53685            1  0,999853481  0,479506831      0,815873016   0,484809472
#
#               O2 n Presion general n
# ...
